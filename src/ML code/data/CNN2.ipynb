# %%
from fastai import *
from fastai.vision import *
from fastai.metrics import error_rate
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 3
#       1 from fastai import *
#       2 from fastai.vision import *
# ----> 3 from fastai.metrics import error_rate
#       4 import os
#       5 import pandas as pd
#
# File ~\AppData\Roaming\Python\Python311\site-packages\fastai\metrics.py:5
#       1 # AUTOGENERATED! DO NOT EDIT! File to edit: ../nbs/13b_metrics.ipynb.
#       2
#       3 # %% ../nbs/13b_metrics.ipynb 1
#       4 from __future__ import annotations
# ----> 5 from .data.all import *
#       6 from .optimizer import *
#       7 from .learner import *
#
# File ~\AppData\Roaming\Python\Python311\site-packages\fastai\data\all.py:1
# ----> 1 from ..torch_basics import *
#       2 from .core import *
#       3 from .load import *
#
# File ~\AppData\Roaming\Python\Python311\site-packages\fastai\torch_basics.py:1
# ----> 1 from torch import multiprocessing
#       2 import platform,os
#       3 if platform.system()=='Darwin':
#       4     # Python 3.8 changed to 'spawn' but that doesn't work with PyTorch DataLoader w n_workers>0
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\__init__.py:141
#     139                 err = ctypes.WinError(ctypes.get_last_error())
#     140                 err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 141                 raise err
#     143     kernel32.SetErrorMode(prev_error_mode)
#     146 def _preload_cuda_deps(lib_folder, lib_name):
#
# OSError: [WinError 126] The specified module could not be found. Error loading "C:\Users\kashi\AppData\Roaming\Python\Python311\site-packages\torch\lib\shm.dll" or one of its dependencies.
